# %%
import csv

def readFile(file):
    scale = 1
    xygrid =[]
    with open(file,'rb') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        i=0
        for row in reader:
            if(i==0):
                scale = float(row[0])

            elif(i>2):  
                grid_row =[]
                for j in range(0,len(row)):
                    grid_row.append(float(row[j]))
                xygrid.append(grid_row)
            
            i+=1
    return (scale,array(xygrid))

# %%
(scale, xygrid) = readFile('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\adams_right_final.csv')
#print xygrid

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import matplotlib.gridspec as gridspec
from pylab import *


def plotGrid(xygrid, e,a,ar):
    row_j = 0
    len_i = xygrid.shape[0]
    len_j = xygrid.shape[1]
    lin_i = arange(0,len_i,1)#linspace(0,len_i,num = len_i)
    lin_j = arange(0,len_j,1)#linspace(0,len_j,num = len_j)
    X,Y = meshgrid(lin_j,lin_i)

    #print len_j
    #print lin_j
    #print len(xygrid[20])
    Z = xygrid
    Z_row = xygrid[row_j,:]
    #print Z.shape
    #print X.shape
    #print Y.shape

    #figure()
    #plot(lin_j,Z_row,'r')
    #show()

    fig = plt.figure(figsize=(14*3,6*3))

    ax = fig.add_subplot(1, 2, 2, projection='3d')
    p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0, antialiased=False)
    cb = fig.colorbar(p, shrink=0.5)

    #ax.set_aspect('equal')
    ax.view_init(elev=e, azim=a)
    ax.set_aspect(ar)
    plt.show()


plotGrid(xygrid,90,90,.5)

# %%
(scale2, xygrid2) = readFile('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample1-Left.csv')

# %%
plotGrid(xygrid2,0,0,1)
plotGrid(xygrid2,0,90,1)
plotGrid(xygrid2,45,45,1)
plotGrid(xygrid2,90,90,1)
plotGrid(xygrid2,90,90,2)

# %% [raw]
# The Cells seem to have a boarder that needs to be trimmed in order to remove. There is also a linear ofset in the hgiedef(dehts

# %%
xy2 = xygrid2
xs,ys = xy2.shape
offset=20
xy3 = xy2[0:xs,offset:ys-offset]
print xy3.shape
plotGrid(xy3,90,90,2)
# Out:
# (161, 138)

# %%
def binaryArray(xygrid,value, bellow_threshold):
    blank = zeros(xygrid.shape)
    for i in range(0,xygrid.shape[0]):
        for j in range(0,xygrid.shape[1]):
            if (value> xygrid[i,j]) and (bellow_threshold==True):
                blank[i,j]=1
            elif(value< xygrid[i,j]) and (bellow_threshold==False):
                blank[i,j]=1
    return blank

# %%
ba=binaryArray(xy2,.1,True)
plotGrid(ba,90,90,2)

# %%
def hough_transform(img_bin, theta_res=1, rho_res=1):
  nR,nC = img_bin.shape
  theta = linspace(-90.0, 0.0, ceil(90.0/theta_res) + 1.0)
  theta = concatenate((theta, -theta[len(theta)-2::-1]))
 
  D = sqrt((nR - 1)**2 + (nC - 1)**2)
  q = ceil(D/rho_res)
  nrho = 2*q + 1
  rho = linspace(-q*rho_res, q*rho_res, nrho)
  H = zeros((len(rho), len(theta)))
  for rowIdx in range(nR):
    for colIdx in range(nC):
      if img_bin[rowIdx, colIdx]:
        for thIdx in range(len(theta)):
          rhoVal = colIdx*cos(theta[thIdx]*pi/180.0) + \
              rowIdx*sin(theta[thIdx]*pi/180)
          rhoIdx = nonzero(abs(rho-rhoVal) == min(abs(rho-rhoVal)))[0]
          H[rhoIdx[0], thIdx] += 1
  return rho, theta, H

# %%
Rho,Theta,H = hough_transform(ba)
plotGrid(H,90,90,1)

# %%
y = -cos(theta)/sin(theta) x + rho/sin(theta)
http://en.wikipedia.org/wiki/Hough_transform
    http://nabinsharma.wordpress.com/2012/12/26/linear-hough-transform-using-python/
        http://pages.physics.cornell.edu/~myers/teaching/ComputationalMethods/python/arrays.html

# %%
def maxpoints(H,percent):
    maxp = amax(H)
    points=[]
    for i in range(0,H.shape[0]):
        for j in range(0,H.shape[1]):
            if percent*maxp <H[i,j] :
                points.append((i,j))
    return points

print maxpoints(H,.999)
# Out:
# [(244, 92), (416, 90), (416, 91)]

# %%
def YfromRhoTheta(r,t,X):
    def y(r,t,x):
        return -cos(t)/sin(t) * x + r/sin(t)
    Y = zeros((X.shape[0],1))
    for i in range(0,X.shape[0]):
        Y[i] = y(r,t,X[i])
    return Y

X = arange(0,xy2.shape[0],1)
Y = arange(0,xy2.shape[1],1)
Y1 = YfromRhoTheta(Rho[244]+5,pi/90.0*Theta[92],Y)
Y2 = YfromRhoTheta(Rho[416]-8,pi/90.0*Theta[91],Y)

fig, ax = plt.subplots(1,1)
ax.plot(Y,Y1,'w')
ax.plot(Y,Y2,'y')
ax.imshow(xy2)
#print "C=",Rho[416]/sin(pi/90.0*Theta[91])
#print "M=",-cos(pi/90.0*Theta[91])/sin(pi/90.0*Theta[91])
#print "R=",Rho[416]
#print "Theta=",Theta[91]
#print Y1
# Out:
# C= 5071.70637757
# M= -28.6362532829
# R= 177.0
# Theta= 1.0

# %%
def plotWithLines(filename):
        (scale2, xy2) = readFile(filename)
        #plotGrid(xy2,90,90,2)
        ba=binaryArray(xy2,.1,True)
        #plotGrid(ba,90,90,2)
        Rho,Theta,H = hough_transform(ba)
        plotGrid(H,90,90,1)
        points = maxpoints(H,.9)
        
        print points
        
        X = arange(0,xy2.shape[0],1)
        Y = arange(0,xy2.shape[1],1)
        Ys=[]
        for point in points:
            if (Theta[point[1]]>0.01):
                C = Rho[point[0]]/sin(pi/90.0*Theta[point[1]])
                print C
                offset=0
                if (C>(scale2*xy2.shape[0]/2.0)):
                    offset = 0
                    print "minus: ", offset
                else:
                    offset = 0
                    print "plus: ",offset
                Y1 = YfromRhoTheta( Rho[point[0]]+offset, pi/90.0*Theta[point[1]], Y)
                Ys.append(Y1)
        fig, ax = plt.subplots(1,1)
        for Ylist in Ys:
            ax.plot(Y,Ylist,'w')
        ax.imshow(xy2)

        
plotWithLines('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample2-Left.csv')
# Out:
# [(246, 90), (247, 90), (247, 91), (248, 91), (248, 92), (249, 91), (249, 92), (250, 91), (250, 92), (250, 93), (251, 92), (251, 93), (252, 92), (252, 93)]
# 229.229666783
# minus:  0
# 257.883375131
# minus:  0
# 129.020283236
# plus:  0
# 286.537083478
# minus:  0
# 143.355870262
# plus:  0
# 315.190791826
# minus:  0
# 157.691457288
# plus:  0
# 105.234494569
# plus:  0
# 172.027044314
# minus:  0
# 114.801266802
# plus:  0
# 186.362631341
# minus:  0
# 124.368039036
# plus:  0

# %%
plotWithLines('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample3-Left.csv')
# Out:
# [(243, 90), (245, 90), (256, 91), (257, 91), (258, 92), (259, 92), (260, 91), (416, 89), (416, 90), (417, 90), (418, 90), (419, 91), (420, 91), (421, 92), (422, 92)]
# 372.498208522
# minus:  0
# 401.15191687
# minus:  0
# 215.033805393
# minus:  0
# 229.369392419
# minus:  0
# 487.113041913
# minus:  0
# 5043.05266922
# minus:  0
# 5071.70637757
# minus:  0
# 2551.73449066
# minus:  0
# 2566.07007769
# minus:  0

# %%
plotWithLines('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample4-Left.csv')
# Out:
# [(253, 91), (254, 91), (255, 92), (425, 89), (425, 90), (426, 90), (427, 90), (427, 91), (428, 90), (428, 91)]
# 143.268541739
# plus:  0
# 171.922250087
# minus:  0
# 100.349109183
# plus:  0
# 5129.01379426
# minus:  0
# 5157.66750261
# minus:  0

# %%
plotWithLines('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample4-Right.csv')
# Out:
# [(245, 90), (248, 91), (418, 92), (418, 93), (419, 92), (420, 93), (421, 93), (421, 94), (422, 94), (422, 95)]
# 85.9611250435
# plus:  0
# 2480.05655553
# minus:  0
# 1655.0515964
# minus:  0
# 2494.39214256
# minus:  0
# 1674.18514086
# minus:  0
# 1683.7519131
# minus:  0
# 1264.61219004
# minus:  0
# 1271.79748658
# minus:  0
# 1019.30237552
# minus:  0

# %% [raw]
# Given these results, we need to sort between the diffrent lines to find the left and right lines. The solution is to find the two inner interesctions points for each side

# %%
def plotWithLines2(filename):
        (scale2, xy2) = readFile(filename)
        #plotGrid(xy2,90,90,2)
        ba=binaryArray(xy2,.1,True)
        #plotGrid(ba,90,90,2)
        Rho,Theta,H = hough_transform(ba)
        #plotGrid(H,90,90,1)
        points = maxpoints(H,.92)
        
        #print points
        
        
        X = arange(0,xy2.shape[0],1)
        Y = arange(0,xy2.shape[1],1)
        Ys=[]
        Left_pxo=-10*xy2.shape[0]
        Left_pxm=-10*xy2.shape[0]
        Right_pxo=10*xy2.shape[0]
        Right_pxm=10*xy2.shape[0]
        
        
        midpoint = xy2.shape[0]/2
        print "MidPoint: ",midpoint
        
        for point in points:
            if (Theta[point[1]]>0.01):
                C = Rho[point[0]]/sin(pi/90.0*Theta[point[1]])
                M = -cos(pi/90.0*Theta[point[1]])/sin(pi/90.0*Theta[point[1]])
                
                #print ""
                #print "C: ",C
                #print "M: ",M
                pxo = (-C/M)
                pxm = (xy2.shape[1]-C)/M
                #print "Px_o: ",pxo
                #print "Px_m: ",pxm
                
                if(pxo<midpoint and pxm<midpoint):
                    if pxo>Left_pxo : Left_pxo = pxo
                    if pxm>Left_pxm : Left_pxm = pxm
                elif(pxo>midpoint and pxm>midpoint):
                    if pxo<Right_pxo : Right_pxo = pxo
                    if pxm<Right_pxm : Right_pxm = pxm
        #print "Left: (",0,",",Left_pxo,") , (",xy2.shape[1],",",Left_pxm,")"
        #print "Right: (",0,",",Right_pxo,") , (",xy2.shape[1],",",Right_pxm,")"
        
        
        def makeY (m,c,X,vertical=False):
            Y = zeros((X.shape[0],1))
            for i in range(0,X.shape[0]):
                Y[i] = m*X[i]-c*m
            return Y
        
        offset = 8
        
        
        
        if( (Right_pxm - Right_pxo)!=0):
            Right_m = xy2.shape[1]/(Right_pxm-Right_pxo)
            RightYs = makeY(Right_m,Right_pxo-offset,Y)
        else:
            RightYs = makeY(1000000,xy2.shape[0]-offset,Y)
        
        if( (Left_pxm - Left_pxo)!=0):
            Left_m = xy2.shape[1]/(Left_pxm-Left_pxo)
            LeftYs = makeY(Left_m,Left_pxo+offset,Y)
        else:
            LeftYs = makeY(1000000,0+offset,Y)
        
        
        #LeftYs = makeY(Left_m,Left_pxo+10,Y)
        #RightYs = makeY(Right_m,Right_pxo-10,Y)

        
        
        
#                offset=0
#                if (C>(scale2*xy2.shape[0]/2.0)):
#                    offset = 0
#                    print "minus: ", offset
#                else:
#                    offset = 0
#                    print "plus: ",offset
#                Y1 = YfromRhoTheta( Rho[point[0]]+offset, pi/90.0*Theta[point[1]], Y)
#                Ys.append(Y1)
        fig, ax = plt.subplots(1,1)
        ax.plot(Y,LeftYs,'w')
        ax.plot(Y,RightYs,'w')
        ax.imshow(xy2)
        
        print LeftYs.shape
        print RightYs.shape
        print xy2.shape
        
        return xy2, LeftYs,RightYs

# %%
a,b = plotWithLines2('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample4-Right.csv')
# Out:
# MidPoint:  83
# (array([[  2.29142391e+02],
#        [  2.00506138e+02],
#        [  1.71869885e+02],
#        [  1.43233632e+02],
#        [  1.14597378e+02],
#        [  8.59611250e+01],
#        [  5.73248718e+01],
#        [  2.86886185e+01],
#        [  5.23651948e-02],
#        [ -2.85838881e+01],
#        [ -5.72201414e+01],
#        [ -8.58563947e+01],
#        [ -1.14492648e+02],
#        [ -1.43128901e+02],
#        [ -1.71765155e+02],
#        [ -2.00401408e+02],
#        [ -2.29037661e+02],
#        [ -2.57673914e+02],
#        [ -2.86310168e+02],
#        [ -3.14946421e+02],
#        [ -3.43582674e+02],
#        [ -3.72218927e+02],
#        [ -4.00855181e+02],
#        [ -4.29491434e+02],
#        [ -4.58127687e+02],
#        [ -4.86763941e+02],
#        [ -5.15400194e+02],
#        [ -5.44036447e+02],
#        [ -5.72672700e+02],
#        [ -6.01308954e+02],
#        [ -6.29945207e+02],
#        [ -6.58581460e+02],
#        [ -6.87217714e+02],
#        [ -7.15853967e+02],
#        [ -7.44490220e+02],
#        [ -7.73126473e+02],
#        [ -8.01762727e+02],
#        [ -8.30398980e+02],
#        [ -8.59035233e+02],
#        [ -8.87671487e+02],
#        [ -9.16307740e+02],
#        [ -9.44943993e+02],
#        [ -9.73580246e+02],
#        [ -1.00221650e+03],
#        [ -1.03085275e+03],
#        [ -1.05948901e+03],
#        [ -1.08812526e+03],
#        [ -1.11676151e+03],
#        [ -1.14539777e+03],
#        [ -1.17403402e+03],
#        [ -1.20267027e+03],
#        [ -1.23130653e+03],
#        [ -1.25994278e+03],
#        [ -1.28857903e+03],
#        [ -1.31721529e+03],
#        [ -1.34585154e+03],
#        [ -1.37448779e+03],
#        [ -1.40312405e+03],
#        [ -1.43176030e+03],
#        [ -1.46039655e+03],
#        [ -1.48903281e+03],
#        [ -1.51766906e+03],
#        [ -1.54630531e+03],
#        [ -1.57494157e+03],
#        [ -1.60357782e+03],
#        [ -1.63221407e+03],
#        [ -1.66085033e+03],
#        [ -1.68948658e+03],
#        [ -1.71812283e+03],
#        [ -1.74675909e+03],
#        [ -1.77539534e+03],
#        [ -1.80403159e+03],
#        [ -1.83266784e+03],
#        [ -1.86130410e+03],
#        [ -1.88994035e+03],
#        [ -1.91857660e+03],
#        [ -1.94721286e+03],
#        [ -1.97584911e+03],
#        [ -2.00448536e+03],
#        [ -2.03312162e+03],
#        [ -2.06175787e+03],
#        [ -2.09039412e+03],
#        [ -2.11903038e+03],
#        [ -2.14766663e+03],
#        [ -2.17630288e+03],
#        [ -2.20493914e+03],
#        [ -2.23357539e+03],
#        [ -2.26221164e+03],
#        [ -2.29084790e+03],
#        [ -2.31948415e+03],
#        [ -2.34812040e+03],
#        [ -2.37675666e+03],
#        [ -2.40539291e+03],
#        [ -2.43402916e+03],
#        [ -2.46266542e+03],
#        [ -2.49130167e+03],
#        [ -2.51993792e+03],
#        [ -2.54857418e+03],
#        [ -2.57721043e+03],
#        [ -2.60584668e+03],
#        [ -2.63448294e+03],
#        [ -2.66311919e+03],
#        [ -2.69175544e+03],
#        [ -2.72039170e+03],
#        [ -2.74902795e+03],
#        [ -2.77766420e+03],
#        [ -2.80630046e+03],
#        [ -2.83493671e+03],
#        [ -2.86357296e+03],
#        [ -2.89220922e+03],
#        [ -2.92084547e+03],
#        [ -2.94948172e+03],
#        [ -2.97811798e+03],
#        [ -3.00675423e+03],
#        [ -3.03539048e+03],
#        [ -3.06402674e+03],
#        [ -3.09266299e+03],
#        [ -3.12129924e+03],
#        [ -3.14993550e+03],
#        [ -3.17857175e+03],
#        [ -3.20720800e+03],
#        [ -3.23584426e+03],
#        [ -3.26448051e+03],
#        [ -3.29311676e+03],
#        [ -3.32175302e+03],
#        [ -3.35038927e+03],
#        [ -3.37902552e+03],
#        [ -3.40766178e+03],
#        [ -3.43629803e+03],
#        [ -3.46493428e+03],
#        [ -3.49357054e+03],
#        [ -3.52220679e+03],
#        [ -3.55084304e+03],
#        [ -3.57947930e+03],
#        [ -3.60811555e+03],
#        [ -3.63675180e+03],
#        [ -3.66538806e+03],
#        [ -3.69402431e+03],
#        [ -3.72266056e+03],
#        [ -3.75129681e+03],
#        [ -3.77993307e+03],
#        [ -3.80856932e+03],
#        [ -3.83720557e+03],
#        [ -3.86584183e+03],
#        [ -3.89447808e+03],
#        [ -3.92311433e+03],
#        [ -3.95175059e+03],
#        [ -3.98038684e+03],
#        [ -4.00902309e+03],
#        [ -4.03765935e+03],
#        [ -4.06629560e+03],
#        [ -4.09493185e+03],
#        [ -4.12356811e+03],
#        [ -4.15220436e+03],
#        [ -4.18084061e+03],
#        [ -4.20947687e+03],
#        [ -4.23811312e+03],
#        [ -4.26674937e+03],
#        [ -4.29538563e+03],
#        [ -4.32402188e+03],
#        [ -4.35265813e+03],
#        [ -4.38129439e+03],
#        [ -4.40993064e+03],
#        [ -4.43856689e+03],
#        [ -4.46720315e+03],
#        [ -4.49583940e+03],
#        [ -4.52447565e+03],
#        [ -4.55311191e+03],
#        [ -4.58174816e+03],
#        [ -4.61038441e+03],
#        [ -4.63902067e+03],
#        [ -4.66765692e+03],
#        [ -4.69629317e+03],
#        [ -4.72492943e+03],
#        [ -4.75356568e+03],
#        [ -4.78220193e+03],
#        [ -4.81083819e+03],
#        [ -4.83947444e+03],
#        [ -4.86811069e+03],
#        [ -4.89674695e+03],
#        [ -4.92538320e+03],
#        [ -4.95401945e+03]]),
#  array([[ 1441.04920947],
#        [ 1432.49305069],
#        [ 1423.93689192],
#        [ 1415.38073314],
#        [ 1406.82457437],
#        [ 1398.26841559],
#        [ 1389.71225682],
#        [ 1381.15609805],
#        [ 1372.59993927],
#        [ 1364.0437805 ],
#        [ 1355.48762172],
#        [ 1346.93146295],
#        [ 1338.37530417],
#        [ 1329.8191454 ],
#        [ 1321.26298662],
#        [ 1312.70682785],
#        [ 1304.15066907],
#        [ 1295.5945103 ],
#        [ 1287.03835152],
#        [ 1278.48219275],
#        [ 1269.92603397],
#        [ 1261.3698752 ],
#        [ 1252.81371642],
#        [ 1244.25755765],
#        [ 1235.70139887],
#        [ 1227.1452401 ],
#        [ 1218.58908132],
#        [ 1210.03292255],
#        [ 1201.47676378],
#        [ 1192.920605  ],
#        [ 1184.36444623],
#        [ 1175.80828745],
#        [ 1167.25212868],
#        [ 1158.6959699 ],
#        [ 1150.13981113],
#        [ 1141.58365235],
#        [ 1133.02749358],
#        [ 1124.4713348 ],
#        [ 1115.91517603],
#        [ 1107.35901725],
#        [ 1098.80285848],
#        [ 1090.2466997 ],
#        [ 1081.69054093],
#        [ 1073.13438215],
#        [ 1064.57822338],
#        [ 1056.0220646 ],
#        [ 1047.46590583],
#        [ 1038.90974706],
#        [ 1030.35358828],
#        [ 1021.79742951],
#        [ 1013.24127073],
#        [ 1004.68511196],
#        [  996.12895318],
#        [  987.57279441],
#        [  979.01663563],
#        [  970.46047686],
#        [  961.90431808],
#        [  953.34815931],
#        [  944.79200053],
#        [  936.23584176],
#        [  927.67968298],
#        [  919.12352421],
#        [  910.56736543],
#        [  902.01120666],
#        [  893.45504788],
#        [  884.89888911],
#        [  876.34273034],
#        [  867.78657156],
#        [  859.23041279],
#        [  850.67425401],
#        [  842.11809524],
#        [  833.56193646],
#        [  825.00577769],
#        [  816.44961891],
#        [  807.89346014],
#        [  799.33730136],
#        [  790.78114259],
#        [  782.22498381],
#        [  773.66882504],
#        [  765.11266626],
#        [  756.55650749],
#        [  748.00034871],
#        [  739.44418994],
#        [  730.88803116],
#        [  722.33187239],
#        [  713.77571361],
#        [  705.21955484],
#        [  696.66339607],
#        [  688.10723729],
#        [  679.55107852],
#        [  670.99491974],
#        [  662.43876097],
#        [  653.88260219],
#        [  645.32644342],
#        [  636.77028464],
#        [  628.21412587],
#        [  619.65796709],
#        [  611.10180832],
#        [  602.54564954],
#        [  593.98949077],
#        [  585.43333199],
#        [  576.87717322],
#        [  568.32101444],
#        [  559.76485567],
#        [  551.20869689],
#        [  542.65253812],
#        [  534.09637935],
#        [  525.54022057],
#        [  516.9840618 ],
#        [  508.42790302],
#        [  499.87174425],
#        [  491.31558547],
#        [  482.7594267 ],
#        [  474.20326792],
#        [  465.64710915],
#        [  457.09095037],
#        [  448.5347916 ],
#        [  439.97863282],
#        [  431.42247405],
#        [  422.86631527],
#        [  414.3101565 ],
#        [  405.75399772],
#        [  397.19783895],
#        [  388.64168017],
#        [  380.0855214 ],
#        [  371.52936263],
#        [  362.97320385],
#        [  354.41704508],
#        [  345.8608863 ],
#        [  337.30472753],
#        [  328.74856875],
#        [  320.19240998],
#        [  311.6362512 ],
#        [  303.08009243],
#        [  294.52393365],
#        [  285.96777488],
#        [  277.4116161 ],
#        [  268.85545733],
#        [  260.29929855],
#        [  251.74313978],
#        [  243.186981  ],
#        [  234.63082223],
#        [  226.07466345],
#        [  217.51850468],
#        [  208.9623459 ],
#        [  200.40618713],
#        [  191.85002836],
#        [  183.29386958],
#        [  174.73771081],
#        [  166.18155203],
#        [  157.62539326],
#        [  149.06923448],
#        [  140.51307571],
#        [  131.95691693],
#        [  123.40075816],
#        [  114.84459938],
#        [  106.28844061],
#        [   97.73228183],
#        [   89.17612306],
#        [   80.61996428],
#        [   72.06380551],
#        [   63.50764673],
#        [   54.95148796],
#        [   46.39532918],
#        [   37.83917041],
#        [   29.28301164],
#        [   20.72685286],
#        [   12.17069409],
#        [    3.61453531],
#        [   -4.94162346],
#        [  -13.49778224],
#        [  -22.05394101],
#        [  -30.61009979],
#        [  -39.16625856],
#        [  -47.72241734],
#        [  -56.27857611],
#        [  -64.83473489],
#        [  -73.39089366],
#        [  -81.94705244],
#        [  -90.50321121],
#        [  -99.05936999],
#        [ -107.61552876]]))

# %%
plotWithLines2('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample3-Left.csv')
# Out:
# [(243, 90), (256, 91), (257, 91), (258, 92), (259, 92), (260, 91), (416, 89), (416, 90), (417, 90), (418, 90), (419, 91), (420, 91), (421, 92), (422, 92)]
# MidPoint:  81
#
# C:  372.498208522
# M:  -28.6362532829
# Px_o:  13.0079240759
# Px_m:  6.61742325889
#
# C:  401.15191687
# M:  -28.6362532829
# Px_o:  14.0085336202
# Px_m:  7.61803280319
#
# C:  215.033805393
# M:  -14.3006662567
# Px_o:  15.0366284712
# Px_m:  2.24002188556
#
# C:  229.369392419
# M:  -14.3006662567
# Px_o:  16.0390703693
# Px_m:  3.24246378364
#
# C:  487.113041913
# M:  -28.6362532829
# Px_o:  17.0103622531
# Px_m:  10.6198614361
#
# C:  5043.05266922
# M:  -28.6362532829
# Px_o:  176.107279797
# Px_m:  169.71677898
#
# C:  5071.70637757
# M:  -28.6362532829
# Px_o:  177.107889341
# Px_m:  170.717388524
#
# C:  2551.73449066
# M:  -14.3006662567
# Px_o:  178.434657858
# Px_m:  165.638051273
#
# C:  2566.07007769
# M:  -14.3006662567
# Px_o:  179.437099757
# Px_m:  166.640493171
# Left: ( 0 , 17.0103622531 ) , ( 183 , 10.6198614361 )
# Right: ( 0 , 176.107279797 ) , ( 183 , 165.638051273 )

# %%
plotWithLines2('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample2-Left.csv')
# Out:
# [(246, 90), (247, 90), (247, 91), (248, 91), (248, 92), (249, 91), (249, 92), (250, 91), (250, 92), (251, 92), (251, 93), (252, 92), (252, 93)]
# MidPoint:  80
#
# C:  229.229666783
# M:  -28.6362532829
# Px_o:  8.00487635439
# Px_m:  1.78897938486
#
# C:  257.883375131
# M:  -28.6362532829
# Px_o:  9.00548589869
# Px_m:  2.78958892916
#
# C:  129.020283236
# M:  -14.3006662567
# Px_o:  9.02197708273
# Px_m:  -3.42499544321
#
# C:  286.537083478
# M:  -28.6362532829
# Px_o:  10.006095443
# Px_m:  3.79019847346
#
# C:  143.355870262
# M:  -14.3006662567
# Px_o:  10.0244189808
# Px_m:  -2.42255354513
#
# C:  315.190791826
# M:  -28.6362532829
# Px_o:  11.0067049873
# Px_m:  4.79080801776
#
# C:  157.691457288
# M:  -14.3006662567
# Px_o:  11.0268608789
# Px_m:  -1.42011164705
#
# C:  172.027044314
# M:  -14.3006662567
# Px_o:  12.029302777
# Px_m:  -0.417669748971
#
# C:  114.801266802
# M:  -9.51436445422
# Px_o:  12.0660993548
# Px_m:  -6.64245452253
#
# C:  186.362631341
# M:  -14.3006662567
# Px_o:  13.0317446751
# Px_m:  0.58477214911
#
# C:  124.368039036
# M:  -9.51436445422
# Px_o:  13.0716076343
# Px_m:  -5.63694624296
# Left: ( 0 , 13.0716076343 ) , ( 178 , 4.79080801776 )
# Right: ( 0 , 1610 ) , ( 178 , 1610 )

# %%
plotWithLines2('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample1-Left.csv')
# Out:
# [(244, 92), (246, 93), (247, 93), (416, 90), (416, 91), (417, 92)]
# MidPoint:  80
#
# C:  71.677935131
# M:  -14.3006662567
# Px_o:  5.01220949041
# Px_m:  -7.43476303554
#
# C:  66.9674056345
# M:  -9.51436445422
# Px_o:  7.03855795694
# Px_m:  -11.6699959203
#
# C:  76.534177868
# M:  -9.51436445422
# Px_o:  8.04406623651
# Px_m:  -10.6644876408
#
# C:  5071.70637757
# M:  -28.6362532829
# Px_o:  177.107889341
# Px_m:  170.891992371
#
# C:  2551.73449066
# M:  -14.3006662567
# Px_o:  178.434657858
# Px_m:  165.987685333
# Left: ( 0 , 8.04406623651 ) , ( 178 , -7.43476303554 )
# Right: ( 0 , 177.107889341 ) , ( 178 , 165.987685333 )

# %%
def cleanBoarders(LeftYs, RightYs, xygrid):
    value = amax(xygrid)
    print value
    print LeftYs.shape
    print RightYs.shape
    print xygrid.shape
    
    for i in range(0,xygrid.shape[0]):
        value = median(xygrid[i,:])
        for j in range(0,xygrid.shape[1]):
            if i<LeftYs[j]:
                
                xygrid[i,j]=0
            elif i>RightYs[j]:
                xygrid[i,j]=0
    return xygrid


xy, Lefty, righty = plotWithLines2('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample1-Left.csv')

cleangrid = cleanBoarders(Lefty,righty,xy)

plotGrid(cleangrid,65,65,2)
# Out:
# MidPoint:  80
# (178, 1)
# (178, 1)
# (161, 178)
# 66.8913
# (178, 1)
# (178, 1)
# (161, 178)

# %%
from scipy import ndimage
sx = ndimage.sobel(cleangrid,axis=0,mode='constant')
sy = ndimage.sobel(cleangrid,axis=1,mode="constant")
sob = hypot(sx,sy)

plt.figure(figsize=(16, 5))
plt.subplot(111)
plt.imshow(sob)

# %%
plotGrid(sob,65,65,2)

# %%
from scipy import stats
newgrid = stats.threshold(sob,threshmin=0,threshmax=120,newval=-1)
plotGrid(newgrid,90,90,2)

# %%
xy, Lefty, righty = plotWithLines2('C:\\Users\\Jeffrey\\Documents\\GitHub\\ScanProcessing\\Software\\python\\Box1-sample1-Left.csv')
sx2 = ndimage.sobel(xy,axis=0,mode='constant')
sy2 = ndimage.sobel(xy,axis=1,mode="constant")
sob2 = hypot(sx2,sy2)
plt.figure(figsize=(16, 5))
plt.subplot(111)
plt.imshow(sob2)
# Out:
# MidPoint:  80
# (178, 1)
# (178, 1)
# (161, 178)

# %%
newgrid = stats.threshold(sob2,threshmin=5,threshmax=120,newval=0)
plotGrid(newgrid,90,90,2)

# %%
cleangrid = cleanBoarders(Lefty,righty,newgrid)
plotGrid(cleangrid,90,90,2)
# Out:
# 119.912194312
# (178, 1)
# (178, 1)
# (161, 178)

# %%
ba=binaryArray(cleangrid,.0001,False)
plotGrid(ba,90,90,2)

# %%
open_img = ndimage.binary_opening(ba)
close_img = ndimage.binary_closing(open_img)

a = ndimage.morphology.binary_erosion(close_img, iterations=3)

plt.figure(figsize=(12*2, 3*2))
plt.subplot(151)
plt.imshow(cleangrid, cmap=plt.cm.gray)
plt.contour(cleangrid, [0.5], linewidths=2, colors='r')
plt.subplot(152)
plt.imshow(ba, cmap=plt.cm.gray)
plt.contour(ba, [0.5], linewidths=2, colors='r')
plt.subplot(153)
plt.imshow(close_img, cmap=plt.cm.gray)
plt.contour(close_img, [0.5], linewidths=2, colors='r')

plt.subplot(154)
plt.imshow(a, cmap=plt.cm.gray)
plt.contour(a, [0.5], linewidths=2, colors='r')
plt.subplot(155)
plt.imshow(cleangrid, cmap=plt.cm.gray)
plt.contour(close_img, [0.5], linewidths=2, colors='r')
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x047B32B0>
